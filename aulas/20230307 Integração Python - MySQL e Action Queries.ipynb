# %% [markdown]
# # Integração Python-SQL
#
# Até agora vimos como construir *queries* dentro de um ambiente SQL (através do cliente *DBeaver*). Embora a utilização de um cliente seja fundamental para explorar o banco de dados e construir *queries* de forma mais rápida, ele não contém ferramentas analíticas (tabelas, funções matemáticas complexas, gráficos, modelos, etc).
#
# Para acessar funções analíticas podemos utilizar outras ferramentas como **clientes** do nosso banco de dados: desde o Excel até Python e Tableau. Na aula de hoje veremos como conectar o Python ao nosso servidor MySQL e extrair dados para análise.
#
# Vamos utilizar a biblioteca **pymysql** para realizar essa conexão. Além disso utilizaremos a biblioteca **sqlalchemy** para executar queries em nosso banco.
#
# ## PyMySQL + SQLAlchemy

# %%
# !pip install pymysql

# %%
from sqlalchemy import create_engine

# %%
import sqlalchemy

# %%
import sqlalchemy
print(sqlalchemy.__version__)
# Out:
# 1.4.39

# %% [markdown]
# Primeiro precisamos especificar os **parâmetros de conexão** ao nosso banco de dados:

# %%
user = "root"
password = "swpmlu23-"
url_banco = "localhost"
nome_db = "bank"
conn_str = f"mysql+pymysql://{user}:{password}@{url_banco}/{nome_db}"
print(conn_str)
# Out:
# mysql+pymysql://root:swpmlu23-@localhost/bank

# %% [markdown]
# Agora vamos utilizar o string de conexão `conn_str` para criar um objeto `engine`:

# %%
engine = create_engine(conn_str)
print(engine)
# Out:
# Engine(mysql+pymysql://root:***@localhost/bank)

# %% [markdown]
# Para executar um query basta utilizarmos o método `.execute()` de um `Engine`:

# %%
results = engine.execute("SELECT * FROM account")
print(results)
# Out:
# <sqlalchemy.engine.cursor.LegacyCursorResult object at 0x7fbb129b1130>

# %% [markdown]
# O resultado do método é um **cursor**: ele ainda não contém os resultados de nosso query. Para extrair-los utilizaremos o método `.fetchall()`:

# %%
dados = results.fetchall()
dados
# Out:
# [(1, 18, 'POPLATEK MESICNE', 950324),
#  (2, 1, 'POPLATEK MESICNE', 930226),
#  (3, 5, 'POPLATEK MESICNE', 970707),
#  (4, 12, 'POPLATEK MESICNE', 960221),
#  (5, 15, 'POPLATEK MESICNE', 970530),
#  (6, 51, 'POPLATEK MESICNE', 940927),
#  (7, 60, 'POPLATEK MESICNE', 961124),
#  (8, 57, 'POPLATEK MESICNE', 950921),
#  (9, 70, 'POPLATEK MESICNE', 930127),
#  (10, 54, 'POPLATEK MESICNE', 960828),
#  (11, 76, 'POPLATEK MESICNE', 951010),
#  (12, 21, 'POPLATEK MESICNE', 970415),
#  (13, 76, 'POPLATEK MESICNE', 970817),
#  (14, 47, 'POPLATEK MESICNE', 961127),
#  (15, 70, 'POPLATEK MESICNE', 931002),
#  (16, 12, 'POPLATEK MESICNE', 970923),
#  (17, 1, 'POPLATEK MESICNE', 970108),
#  (18, 43, 'POPLATEK TYDNE', 930526),
#  (19, 21, 'POPLATEK MESICNE', 950407),
#  (20, 74, 'POPLATEK MESICNE', 960824),
#  (21, 54, 'POPLATEK MESICNE', 971206),
#  (22, 1, 'POPLATEK MESICNE', 940323),
#  (23, 30, 'POPLATEK MESICNE', 930522),
#  (24, 74, 'POPLATEK MESICNE', 961205),
#  (809, 36, 'POPLATEK MESICNE', 951220),
#  (810, 46, 'POPLATEK MESICNE', 951111),
#  (811, 14, 'POPLATEK TYDNE', 970801),
#  (812, 1, 'POPLATEK MESICNE', 960830),
#  (813, 16, 'POPLATEK MESICNE', 930210),
#  (814, 76, 'POPLATEK MESICNE', 961006),
#  (815, 56, 'POPLATEK MESICNE', 930825),
#  (816, 52, 'POPLATEK MESICNE', 930805),
#  (817, 5, 'POPLATEK MESICNE', 940318),
#  (819, 20, 'POPLATEK MESICNE', 950422),
#  (820, 74, 'POPLATEK MESICNE', 951104),
#  (821, 60, 'POPLATEK MESICNE', 960316),
#  (822, 40, 'POPLATEK MESICNE', 961004),
#  (823, 71, 'POPLATEK MESICNE', 970919),
#  (824, 32, 'POPLATEK MESICNE', 960321),
#  (825, 19, 'POPLATEK MESICNE', 960306),
#  (826, 44, 'POPLATEK MESICNE', 961005),
#  (827, 36, 'POPLATEK MESICNE', 960223),
#  (828, 1, 'POPLATEK MESICNE', 970212),
#  (829, 59, 'POPLATEK MESICNE', 961110),
#  (830, 74, 'POPLATEK MESICNE', 930208),
#  (831, 44, 'POPLATEK MESICNE', 960918),
#  (832, 42, 'POPLATEK MESICNE', 960524),
#  (833, 31, 'POPLATEK MESICNE', 960829),
#  (834, 3, 'POPLATEK MESICNE', 970523),
#  (836, 46, 'POPLATEK MESICNE', 960728),
#  (837, 46, 'POPLATEK MESICNE', 930918),
#  (838, 47, 'POPLATEK MESICNE', 931023),
#  (839, 16, 'POPLATEK MESICNE', 950117),
#  (840, 70, 'POPLATEK MESICNE', 960312),
#  (841, 1, 'POPLATEK MESICNE', 931104),
#  (842, 62, 'POPLATEK MESICNE', 950407),
#  (843, 6, 'POPLATEK MESICNE', 970409),
#  (844, 53, 'POPLATEK MESICNE', 940428),
#  (845, 14, 'POPLATEK MESICNE', 971227),
#  (846, 72, 'POPLATEK MESICNE', 960309),
#  (847, 2, 'POPLATEK MESICNE', 960721),
#  (848, 31, 'POPLATEK MESICNE', 960616),
#  (849, 1, 'POPLATEK MESICNE', 960101),
#  (850, 25, 'POPLATEK MESICNE', 970307),
#  (851, 15, 'POPLATEK MESICNE', 940923),
#  (852, 57, 'POPLATEK MESICNE', 971023),
#  (853, 1, 'POPLATEK MESICNE', 960320),
#  (854, 62, 'POPLATEK MESICNE', 930921),
#  (855, 1, 'POPLATEK MESICNE', 940328),
#  (856, 2, 'POPLATEK MESICNE', 960303),
#  (857, 77, 'POPLATEK MESICNE', 930916),
#  (858, 52, 'POPLATEK MESICNE', 960713),
#  (859, 13, 'POPLATEK MESICNE', 970826),
#  (860, 1, 'POPLATEK MESICNE', 930319),
#  (861, 22, 'POPLATEK MESICNE', 930913),
#  (862, 64, 'POPLATEK TYDNE', 930202),
#  (863, 71, 'POPLATEK MESICNE', 930516),
#  (864, 72, 'POPLATEK MESICNE', 970708),
#  (865, 17, 'POPLATEK MESICNE', 960318),
#  (866, 9, 'POPLATEK MESICNE', 930110),
#  (867, 60, 'POPLATEK MESICNE', 971109),
#  (868, 1, 'POPLATEK MESICNE', 970526),
#  (869, 16, 'POPLATEK MESICNE', 960715),
#  (870, 70, 'POPLATEK MESICNE', 950327),
#  (871, 1, 'POPLATEK MESICNE', 960902),
#  (872, 27, 'POPLATEK MESICNE', 970118),
#  (873, 73, 'POPLATEK MESICNE', 970426),
#  (874, 56, 'POPLATEK TYDNE', 960323),
#  (875, 63, 'POPLATEK MESICNE', 950517),
#  (876, 4, 'POPLATEK MESICNE', 971026),
#  (877, 1, 'POPLATEK MESICNE', 960529),
#  (878, 52, 'POPLATEK MESICNE', 960629),
#  (879, 9, 'POPLATEK MESICNE', 970604),
#  (880, 26, 'POPLATEK MESICNE', 961208),
#  (882, 9, 'POPLATEK MESICNE', 930306),
#  (883, 1, 'POPLATEK MESICNE', 931217),
#  (884, 2, 'POPLATEK MESICNE', 931207),
#  (885, 1, 'POPLATEK MESICNE', 930625),
#  (886, 1, 'POPLATEK MESICNE', 930623),
#  (887, 1, 'POPLATEK MESICNE', 930505),
#  (888, 54, 'POPLATEK MESICNE', 961028),
#  (889, 43, 'POPLATEK MESICNE', 971222),
#  (890, 14, 'POPLATEK MESICNE', 930205),
#  (891, 34, 'POPLATEK MESICNE', 960523),
#  (892, 70, 'POPLATEK MESICNE', 930320),
#  (893, 53, 'POPLATEK MESICNE', 950412),
#  (894, 46, 'POPLATEK MESICNE', 950827),
#  (895, 24, 'POPLATEK MESICNE', 960312),
#  (896, 3, 'POPLATEK MESICNE', 950611),
#  (897, 38, 'POPLATEK MESICNE', 930426),
#  (898, 71, 'POPLATEK MESICNE', 960327),
#  (899, 72, 'POPLATEK MESICNE', 930621),
#  (900, 48, 'POPLATEK MESICNE', 940426),
#  (901, 60, 'POPLATEK MESICNE', 940710),
#  (902, 74, 'POPLATEK MESICNE', 930629),
#  (903, 47, 'POPLATEK MESICNE', 931210),
#  (904, 1, 'POPLATEK MESICNE', 940320),
#  (905, 35, 'POPLATEK MESICNE', 961211),
#  (906, 59, 'POPLATEK MESICNE', 971227),
#  (907, 41, 'POPLATEK MESICNE', 930709),
#  (908, 62, 'POPLATEK MESICNE', 940429),
#  (909, 30, 'POPLATEK MESICNE', 970902),
#  (910, 1, 'POPLATEK MESICNE', 970203),
#  (911, 60, 'POPLATEK MESICNE', 960812),
#  (912, 65, 'POPLATEK MESICNE', 970427),
#  (913, 59, 'POPLATEK MESICNE', 960510),
#  (914, 73, 'POPLATEK MESICNE', 931114),
#  (915, 72, 'POPLATEK MESICNE', 950118),
#  (916, 1, 'POPLATEK MESICNE', 960813),
#  (917, 56, 'POPLATEK MESICNE', 951013),
#  (918, 60, 'POPLATEK MESICNE', 960823),
#  (919, 62, 'POPLATEK MESICNE', 970303),
#  (920, 58, 'POPLATEK MESICNE', 960905),
#  (921, 10, 'POPLATEK MESICNE', 961008),
#  (922, 61, 'POPLATEK MESICNE', 950427),
#  (923, 13, 'POPLATEK MESICNE', 960207),
#  (924, 11, 'POPLATEK MESICNE', 951209),
#  (925, 59, 'POPLATEK MESICNE', 930223),
#  (926, 36, 'POPLATEK MESICNE', 961101),
#  (927, 69, 'POPLATEK MESICNE', 970412),
#  (928, 20, 'POPLATEK MESICNE', 930426),
#  (929, 54, 'POPLATEK MESICNE', 930703),
#  (930, 41, 'POPLATEK MESICNE', 930803),
#  (931, 59, 'POPLATEK MESICNE', 931015),
#  (932, 20, 'POPLATEK MESICNE', 960708),
#  (933, 21, 'POPLATEK MESICNE', 951118),
#  (934, 9, 'POPLATEK MESICNE', 971127),
#  (935, 23, 'POPLATEK MESICNE', 961225),
#  (936, 7, 'POPLATEK MESICNE', 960302),
#  (937, 43, 'POPLATEK MESICNE', 950826),
#  (938, 70, 'POPLATEK MESICNE', 971213),
#  (939, 55, 'POPLATEK MESICNE', 941004),
#  (940, 37, 'POPLATEK MESICNE', 941115),
#  (941, 8, 'POPLATEK MESICNE', 940608),
#  (942, 9, 'POPLATEK MESICNE', 930816),
#  (943, 1, 'POPLATEK MESICNE', 930203),
#  (944, 70, 'POPLATEK MESICNE', 930308),
#  (945, 18, 'POPLATEK MESICNE', 960816),
#  (946, 21, 'POPLATEK MESICNE', 960101),
#  (947, 59, 'POPLATEK MESICNE', 930517),
#  (949, 58, 'POPLATEK MESICNE', 960213),
#  (950, 49, 'POPLATEK MESICNE', 930826),
#  (951, 3, 'POPLATEK MESICNE', 960428),
#  (952, 41, 'POPLATEK MESICNE', 971109),
#  (953, 14, 'POPLATEK MESICNE', 950722),
#  (954, 74, 'POPLATEK MESICNE', 960108),
#  (955, 59, 'POPLATEK MESICNE', 960708),
#  (956, 74, 'POPLATEK MESICNE', 931205),
#  (957, 70, 'POPLATEK MESICNE', 951222),
#  (958, 72, 'POPLATEK MESICNE', 960606),
#  (959, 1, 'POPLATEK MESICNE', 960223),
#  (960, 4, 'POPLATEK PO OBRATU', 941102),
#  (961, 1, 'POPLATEK MESICNE', 971018),
#  (962, 64, 'POPLATEK MESICNE', 960624),
#  (963, 7, 'POPLATEK MESICNE', 960809),
#  (964, 26, 'POPLATEK MESICNE', 940708),
#  (965, 20, 'POPLATEK MESICNE', 930825),
#  (966, 15, 'POPLATEK MESICNE', 971014),
#  (967, 15, 'POPLATEK MESICNE', 960817),
#  (968, 74, 'POPLATEK MESICNE', 951111),
#  (969, 19, 'POPLATEK MESICNE', 940108),
#  (970, 18, 'POPLATEK MESICNE', 970720),
#  (971, 12, 'POPLATEK MESICNE', 960718),
#  (972, 46, 'POPLATEK MESICNE', 960929),
#  (973, 54, 'POPLATEK MESICNE', 941105),
#  (974, 29, 'POPLATEK MESICNE', 940225),
#  (975, 1, 'POPLATEK MESICNE', 961019),
#  (976, 77, 'POPLATEK MESICNE', 960127),
#  (977, 1, 'POPLATEK MESICNE', 930426),
#  (978, 73, 'POPLATEK MESICNE', 930818),
#  (979, 21, 'POPLATEK MESICNE', 930216),
#  (980, 1, 'POPLATEK MESICNE', 961211),
#  (981, 66, 'POPLATEK MESICNE', 950325),
#  (982, 54, 'POPLATEK MESICNE', 930205),
#  (984, 2, 'POPLATEK MESICNE', 960710),
#  (985, 32, 'POPLATEK MESICNE', 940529),
#  (1046, 1, 'POPLATEK MESICNE', 950414),
#  (1047, 46, 'POPLATEK MESICNE', 940613),
#  ...]

# %% [markdown]
# ## Utilizando Pandas
#
# O resultado do método `.fetchall()` é uma lista. Embora listas sejam facilmente transformadas em `DataFrames`, podemos economizar esforços utilizando a função `read_sql_query()` da biblioteca Pandas.

# %%
import pandas as pd

# %% [markdown]
# Para utilizarmos está função precisaremos do nosso `Engine`, criado através da **SQLAlchemy** na primeira parte da aula.

# %%
with engine.begin() as conn:
    tb_account = pd.read_sql_query(text("SELECT * FROM account"), conn)
tb_account.head()

# %%
tb_account = pd.read_sql_query("SELECT * FROM account", engine)
tb_account.head()
# Out:
#    account_id  district_id         frequency    date
# 0           1           18  POPLATEK MESICNE  950324
# 1           2            1  POPLATEK MESICNE  930226
# 2           3            5  POPLATEK MESICNE  970707
# 3           4           12  POPLATEK MESICNE  960221
# 4           5           15  POPLATEK MESICNE  970530

# %% [markdown]
# Os queries que vimos acima são *one-liners*: simples o suficiente para serem escritos em uma linha de código. Conforme a complexidade de nossos queries aumenta, devemos utilizar *strings multi-line* ou arquivos `.sql` para guardar nossos queries:

# %%
query_loan = '''
SELECT
	l.*,
	c.*
FROM 
	bank.loan l JOIN
	bank.account a ON (l.account_id = a.account_id) JOIN 
	bank.disp d ON (a.account_id = d.account_id) JOIN 
	bank.client c ON (d.client_id = c.client_id)
'''
tb_district_loan = pd.read_sql_query(query_loan, engine)
tb_district_loan.head()
# Out:
#    loan_id  account_id    date  amount  duration  payments status  client_id  \
# 0     4959           2  940105   80952        24    3373.0      A          2
# 1     4959           2  940105   80952        24    3373.0      A          3
# 2     4961          19  960429   30276        12    2523.0      B         25
# 3     4962          25  971208   30276        12    2523.0      A         31
# 4     4967          37  981014  318480        60    5308.0      D         45
#
#    birth_number  district_id
# 0        450204            1
# 1        406009            1
# 2        395423           21
# 3        620209           68
# 4        520826           20

# %% [markdown]
# Outra forma de estruturar nossos queries é salvando-os em arquivos externos `.sql` - dessa forma mantemos separados Python e SQL de uma forma simples:

# %%
fd = open('queries/QUERY_DISTRICT_LOAN.sql', 'r')
sqlFile = fd.read()
fd.close()
print(sqlFile)
# Out:
# SELECT
# 	d.A4 AS total_pop,
# 	d.A9 AS num_cities,
# 	d.A10 AS urb_pop_ratio,
# 	(d.A12 + d.A13) AS avg_unemploy,
# 	(d.A15 + d.A16)/(2 * d.A4) AS avg_crime_rate,
# 	tx_emp_distrito.TX_DEVEDORES AS tx_devedores,
# 	tx_emp_distrito.NUM_EMPRESTIMOS AS num_emprestimos
# FROM
# 	bank.district d JOIN
# 	(
# 		SELECT
# 			c.district_id,
# 			AVG(
# 				CASE
# 					WHEN l.status = 'B' OR l.status = 'D' THEN 1
# 					ELSE 0
# 				END
# 			) AS TX_DEVEDORES,
# 			COUNT(*) AS NUM_EMPRESTIMOS
# 		FROM
# 			bank.client c JOIN
# 			bank.disp d ON (c.client_id = d.client_id) JOIN
# 			bank.account a ON (d.account_id = a.account_id) JOIN
# 			bank.loan l ON (a.account_id = l.account_id) JOIN
# 			bank.district d2 ON (c.district_id = d2.A1)
# 		GROUP BY
# 			c.district_id
# 	) AS TX_EMP_DISTRITO ON (TX_EMP_DISTRITO.district_id = d.a1)

# %%
tb_district_loan = pd.read_sql_query(sqlFile, engine)
tb_district_loan.head()
# Out:
#    total_pop  num_cities  urb_pop_ratio  avg_unemploy  avg_crime_rate  \
# 0    1204953           1          100.0          0.72          0.0767
# 1      88884           5           46.7          3.52          0.0272
# 2      75232           5           41.7          4.16          0.0375
# 3     149893           6           67.4          9.69          0.0371
# 4      95616           6           51.4          8.28          0.0296
#
#    tx_devedores  num_emprestimos
# 0        0.0612               98
# 1        0.0000                9
# 2        0.2500                8
# 3        0.3333                6
# 4        0.0833               12

# %% [markdown]
# # Action Queries
#
# Action queries (o **C**, **U** e **D** em **CRUD**) são queries que realizam alterações em nosso DB:
#
# 1) **CREATE** nos permite criar tabelas e DBs através dos queries:
#     * **CREATE TABLE *nome_tabela* (*coluna_1* *tipo*, *coluna_2* *tipo*, *...*)** para criar tabelas;
#     * **CREATE DATABASE *nome_db*** para criar DBs;
#     * **INSERT INTO *nome_tabela* VALUES (*valor1*, *valor2*, *...*)** para inserir uma nova linha na tabela *nome_tabela* com valores igual à *valor1*, *valor2*, *...*
# 1) **UPDATE** nos permite alterar uma estrutura existente em nosso DB;
#     * **ALTER TABLE *nome_tabela* ADD PRIMARY KEY *nome_coluna*** para criar uma chave primaria em uma tabela existente;
#     * **ALTER TABLE *nome_tabela* ADD FOREIGN KEY (*nome_coluna*) REFERENCES *nome_outra_tabela*(*nome_coluna_2*)** para criar um relação entre as tabelas *nome_tabela* e *nome_outra_tabela* através das colunas *nome_coluna* e *nome_coluna_2*;
#     * **UPDATE *nome_tabela* SET *coluna_1* = *valor1*, *coluna_2* = *valor2* ... WHERE *condição*** para alterar os valores das colunas *coluna_1*, *coluna_2*, *...*, em todas as linhas onde *condição* é verdadeira.
# 1) **DELETE** nos permite excluir objetos do nosso DB;
#     * **DROP DATABASE IF EXISTS *nome_db*** para excluir o DB *nome_db* caso ele exista;
#     * **DROP TABLE IF EXISTS *nome_db.nome_tabela*** para excluir a tabela *nome_tabela* do DB *nome_db*;
#     * **DROP TABLE IF EXISTS *nome_db.nome_tabela* CASCADE** para excluir a tabela *nome_tabela* do DB *nome_db* e todas as tabelas que dependam de *nome_tabela*;
#     * **DELETE FROM *nome_tabela* WHERE *condição*** para excluir todas as linhas ta tabela *nome_tabela* onde *condição* seja verdadeira.
#
#     Vamos criar parte do nosso DB da Ironhack que criamos no sábado utilizando os queries acima:

# %%
engine.execute("DROP DATABASE ironhack")

# %%
engine.execute("CREATE DATABASE ironhack")

# %% [markdown]
# Com o DB criado, vamos criar as tabelas `aluno`, `turma` e `matricula`:

# %%
query_aluno = '''
    CREATE TABLE ironhack.aluno (
        id_aluno int NOT NULL PRIMARY KEY,
        nome varchar(255) NOT NULL,
        email varchar(255)
    )
'''

query_turma = '''
    CREATE TABLE ironhack.turma (
        id_turma int NOT NULL PRIMARY KEY,
        area varchar(255) NOT NULL,
        tipo varchar(255) NOT NULL,
        campus varchar(255) NOT NULL,
        data_inicio date NOT NULL
    )
'''

query_matricula = '''
    CREATE TABLE ironhack.matricula (
        id_matricula int NOT NULL PRIMARY KEY,
        id_aluno int NOT NULL,
        id_turma int NOT NULL,
        data_matricula date NOT NULL,
        FOREIGN KEY (id_turma) REFERENCES ironhack.turma(id_turma)
    )
'''

# %% [markdown]
# Vamos utilizar os queries acima para criar as três tabelas em nosso DB:

# %%
engine.execute(query_aluno)
engine.execute(query_turma)
engine.execute(query_matricula)

# %% [markdown]
# No DB acima não declaramos a relação entre a tabela `matricula` e a tabela `aluno`. Vamos utilizar o **ALTER TABLE** para adicionar essa relação:

# %%
query_fk = '''
    ALTER TABLE ironhack.matricula
    ADD FOREIGN KEY (id_aluno)
    REFERENCES ironhack.aluno(id_aluno)
'''

engine.execute(query_fk)

# %% [markdown]
# Agora vamos criar os dados de nossa escola:

# %%
lista_alunos = [
    (1, 'Guilherme', 'guilherme_93@gmail.com'),
    (2, 'Guilherme', 'guilherme_71@gmail.com'),
    (3, 'Alexa', 'alexa@gmail.com'),
    (4, 'Breno', 'breno@gmail.com'),
    (5, 'Thomas', 'thomas@gmail.com'),
    (6, 'Matheus', 'matheus@gmail.com'),
    (7, 'José', 'jose@gmail.com'),
    (8, 'Maria', 'maria@gmail.com'),
    (9, 'Madalena', 'madalena@gmail.com'),
    (10, 'Miguel', 'miguel@gmail.com'),
    (11, 'Berenice', 'berenice@gmail.com')
]

# %%
lista_turmas = [
    (99, 'DA', 'PT', 'SAO_RMT'),
    (54, 'WD', 'FT', 'SAO_RMT'),
    (112, 'DA', 'FT', 'MEX_RMT')
]

# %%
lista_matriculas = [
    (1, 1, 99),
    (2, 2, 99),
    (3, 3, 99),
    (4, 4, 99),
    (5, 5, 99),
    (6, 6, 99),
    (7, 5, 54),
    (8, 7, 54),
    (9, 8, 54),
    (10, 9, 54),
    (11, 10, 112),
    (11, 11, 112),
]

# %% [markdown]
# Como nossas tabelas tem relações de **depêndencia**, representandas pelas `FOREIGN KEYS`, precisamos começar inserindo os valores nas tabelas **independentes** (em nosso caso, as tabelas `aluno` e `turma`).
#
# Vamos redefinir nosso `engine` para conectarmos o novo DB:

# %%
user = "root"
password = "swpmlu23-"
url_banco = "localhost"
nome_db = "ironhack"
conn_str = f"mysql+pymysql://{user}:{password}@{url_banco}/{nome_db}"
engine = create_engine(conn_str)

# %% [markdown]
# Poderíamos usar um query simples de `INSERT` junto com um loop para inserirmos os dados diretamente através do engine. Mas a biblioteca SQLAlchemy nos fornece um caminho mais simples e eficientes através do objeto `MetaData`:

# %%
from sqlalchemy import MetaData

# %%
meta = MetaData(bind=engine)
meta.reflect()

# %% [markdown]
# Vamos utilizar o objeto `meta` para acessar *simbolicamente* a nossa tabela `aluno`:

# %%
tb_db_alunos = meta.tables['aluno']

# %% [markdown]
# A partir do novo objeto `tb_db_alunos` podemos utilizar o método `.insert().values()` para inserir em massa os nossos dados na tabela.

# %%
load_alunos = tb_db_alunos.insert().values(lista_alunos)
engine.execute(load_alunos)
