# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Análise-Exploratória-de-Dados-(EDA)" data-toc-modified-id="Análise-Exploratória-de-Dados-(EDA)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Análise Exploratória de Dados (EDA)</a></span><ul class="toc-item"><li><span><a href="#Definição-do-Problema" data-toc-modified-id="Definição-do-Problema-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Definição do Problema</a></span></li><li><span><a href="#Fonte-de-Dados" data-toc-modified-id="Fonte-de-Dados-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Fonte de Dados</a></span></li><li><span><a href="#Usando-Paletas-de-Cor" data-toc-modified-id="Usando-Paletas-de-Cor-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Usando Paletas de Cor</a></span></li><li><span><a href="#Distribuição-e-Evolução-de-Avaliações" data-toc-modified-id="Distribuição-e-Evolução-de-Avaliações-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Distribuição e Evolução de Avaliações</a></span></li><li><span><a href="#Explorando-(co)Relações" data-toc-modified-id="Explorando-(co)Relações-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Explorando (co)Relações</a></span></li><li><span><a href="#Relação-entre-uma-variável-continua-e-uma-categórica" data-toc-modified-id="Relação-entre-uma-variável-continua-e-uma-categórica-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Relação entre uma variável continua e uma categórica</a></span></li><li><span><a href="#Análises-multi-variáveis" data-toc-modified-id="Análises-multi-variáveis-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Análises multi-variáveis</a></span></li></ul></li></ul></div>

# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd

from matplotlib import pyplot as plt
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv("credentials/mysql.env")
url_banco = "localhost"
nome_db = "olist"
conn_str = f"mysql+pymysql://{os.getenv('MYSQL_USER')}:{os.getenv('MYSQL_PASS')}@{url_banco}/{nome_db}"
engine = create_engine(conn_str)

# %%
sns.set_theme(context="notebook", style="darkgrid")

# %% [markdown]
# Para facilitar nosso trabalho na aula de hoje, vamos criar um View com os dados que utilizaremos ao longo da aula.

# %% [markdown]
# # Análise Exploratória de Dados (EDA)
#
# O processo de construção de modelos pode ser dividido em quatro etapas:
#
# 1. **Definição do Problema e Coleta de Dados**;
#     * Todo modelo deve ter um **objetivo bem definido**.
#     * O **tempo disponível** para construção é **parte da definição do problema**!
#     * A partir desta definição podemos definir *quais dados serão necessários* para **iniciarmos nossa análise**.
# 1. **Análises Exploratórias**;
#     * O objetivo da análise exploratória é *maximizar o nosso conhecimento* sobre a **estrutura dos dados** disponíveis, mapear as relações entre diferentes variáveis e o objetivo do nosso problema e **avaliar a qualidade dos dados**, eventualmente propondo tratativas para sanar problemas.
# 1. **Definição e construção do modelo**;
#     * A partir do conhecimento adquirido durante a análise exploratória vamos determinar quais **técnicas são mais apropriadas** para a resolução do nosso problema.
#     * Para escolher entre diferentes técnicas devemos **implantar uma infra-estrutura rudimentar de testes**, que nos permita *testar diferentes modelos de forma rápida e simples*.
# 1. **Validação e definição de próximos passos**.
#     * Com a construção do modelo finalizada, conduziremos a validação final do modelo, apresentando os conceitos por trás deste para os diferentes stakeholders do projeto. Além disso conduziremos testes utilizando a infra-estrutura operacional do modelo, garantindo que não houve perda de performance nas condições operacionais.
#
# Este processo **não é necessariamente linear**: podemos descobrir na etapa de análises exploratórias que não temos todas as informações necessárias para construir um modelo, ou então que as informações estão comprometidas a ponto de inviabilizar qualquer análise.
#
# Hoje nos aprofundaremos na segunda etapa deste fluxo: a análise exploratória de dados!
#
# ## Definição do Problema
#
# Para a aula de hoje utilizaremos o data set da Olist. Foi solicitado ao CoE de Dados que construa um modelo para explicar e prever variações nas avalições que clientes fizeram de nossos pedidos. O objetivo deste modelo é descobrir quais são os principais eixos que impactam estas avaliações para que possamos focar esforços na melhoria das áreas mais críticas.
#
# Os dados utilizados serão os dados do case OLIST, disponíveis no nosso DB MySQL.
#
# ## Fonte de Dados
#
# No caso da aula de hoje, utilizaremos o nosso DB MySQL como fonte de dados para nossa análise exploratória.

# %%
query = """
    SELECT
        oodc.order_id,
        ooidc.seller_id,
        ooidc.price,
        ooidc.freight_value,
        oodc.order_status,
        STR_TO_DATE(oodc.order_approved_at, '%%Y-%%m-%%d %%H:%%i:%%s') AS order_approved_at,
        STR_TO_DATE(ooidc.shipping_limit_date, '%%Y-%%m-%%d %%H:%%i:%%s') AS shipping_limit_date,
        STR_TO_DATE(oodc.order_delivered_carrier_date, '%%Y-%%m-%%d %%H:%%i:%%s') AS order_delivered_carrier_date,
        STR_TO_DATE(oodc.order_delivered_customer_date, '%%Y-%%m-%%d %%H:%%i:%%s') AS order_delivered_customer_date,
        STR_TO_DATE(oodc.order_estimated_delivery_date, '%%Y-%%m-%%d %%H:%%i:%%s') AS order_estimated_delivery_date,
        ocdc.customer_state,
        osdc.seller_state,
        opdc.product_category_name,
        opdc.product_weight_g,
        oordc.review_score 
    FROM 
        olist.t_order_item ooidc JOIN
        olist.t_order oodc ON (ooidc.order_id = oodc.order_id) JOIN 
        olist.t_customer ocdc ON (oodc.customer_id = ocdc.customer_id) JOIN 
        olist.t_product opdc ON (ooidc.product_id = opdc.product_id) JOIN
        olist.t_seller osdc ON (osdc.seller_id = ooidc.seller_id) LEFT JOIN 
        olist.t_order_review oordc ON (oodc.order_id = oordc.order_id) JOIN
        (
            SELECT
                oordc.review_id,
                STR_TO_DATE(oordc.review_creation_date, '%%Y-%%m-%%d %%H:%%i:%%s') AS review_date,
                SUM(1) OVER (PARTITION BY order_id ORDER BY order_id, STR_TO_DATE(oordc.review_creation_date, '%%Y-%%m-%%d %%H:%%i:%%s') DESC) AS cum_review
            FROM 
                olist.t_order_review oordc
            ORDER BY 
                oordc.order_id,
                STR_TO_DATE(oordc.review_creation_date, '%%Y-%%m-%%d %%H:%%i:%%s') DESC
        ) AS lr ON (oordc.review_id = lr.review_id)
    WHERE
        lr.cum_review = 1
    HAVING
        order_approved_at >= '2017-08-01' AND
        order_approved_at < '2018-08-01'
"""
tb_pedidos = pd.read_sql(query, engine)

# %%
tb_pedidos.head()
# Out:
#                            order_id                         seller_id   price  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202   58.90
# 1  000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d  199.00
# 2  0005a1a1728c9d785b8e2b08b904576c  a416b6a846a11724393025641d4edd5e  145.95
# 3  0005f50442cb953dcd1d21e1fb923495  ba143b05f0110f0dc71ad71b4466ce92   53.99
# 4  00061f2a7bc09da83e415a52dc8a4af1  cc419e0650a3c5ba77189a1882b7556a   59.99
#
#    freight_value order_status   order_approved_at shipping_limit_date  \
# 0          13.29    delivered 2017-09-13 09:45:35 2017-09-19 09:45:35
# 1          17.87    delivered 2018-01-14 14:48:30 2018-01-18 14:48:30
# 2          11.65    delivered 2018-03-20 18:35:21 2018-03-26 18:31:29
# 3          11.40    delivered 2018-07-02 14:10:56 2018-07-06 14:10:56
# 4           8.88    delivered 2018-03-24 22:28:09 2018-03-29 22:28:09
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-09-19 18:34:16           2017-09-20 23:43:48
# 1          2018-01-16 12:36:48           2018-01-22 13:19:16
# 2          2018-03-28 00:37:42           2018-03-29 18:17:31
# 3          2018-07-03 14:25:00           2018-07-04 17:28:31
# 4          2018-03-27 05:26:55           2018-03-29 00:04:19
#
#   order_estimated_delivery_date customer_state seller_state  \
# 0                    2017-09-29             RJ           SP
# 1                    2018-02-05             MG           MG
# 2                    2018-03-29             SP           SP
# 3                    2018-07-23             SP           SP
# 4                    2018-04-09             SP           SP
#
#   product_category_name  product_weight_g  review_score
# 0            cool_stuff             650.0             5
# 1      moveis_decoracao            3050.0             5
# 2          beleza_saude            2000.0             1
# 3       livros_tecnicos             850.0             4
# 4          beleza_saude             950.0             5

# %%
tb_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66136 entries, 0 to 66135
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       66136 non-null  object
#  1   seller_id                      66136 non-null  object
#  2   price                          66136 non-null  float64
#  3   freight_value                  66136 non-null  float64
#  4   order_status                   66136 non-null  object
#  5   order_approved_at              66136 non-null  datetime64[ns]
#  6   shipping_limit_date            66136 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   65536 non-null  datetime64[ns]
#  8   order_delivered_customer_date  64881 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  66136 non-null  datetime64[ns]
#  10  customer_state                 66136 non-null  object
#  11  seller_state                   66136 non-null  object
#  12  product_category_name          66136 non-null  object
#  13  product_weight_g               66134 non-null  float64
#  14  review_score                   66136 non-null  int64
# dtypes: datetime64[ns](5), float64(3), int64(1), object(6)
# memory usage: 7.6+ MB

# %%
tb_pedidos.describe()
# Out:
#               price  freight_value  product_weight_g  review_score
# count  66136.000000   66136.000000      66134.000000  66136.000000
# mean     120.431259      20.100345       2083.401110      3.996386
# std      174.447365      15.793979       3703.339539      1.415262
# min        0.850000       0.000000          0.000000      1.000000
# 25%       39.990000      13.070000        300.000000      3.000000
# 50%       75.900000      16.360000        668.000000      5.000000
# 75%      135.705000      21.300000       1800.000000      5.000000
# max     4099.990000     409.680000      40425.000000      5.000000

# %%
tb_pedidos.select_dtypes(include=["object"]).describe()
# Out:
#                                 order_id                         seller_id  \
# count                              66136                             66136
# unique                             57274                              2455
# top     1b15974a0141d54e36626dca3fdc731a  1f50f920176fa81dab994f9023523100
# freq                                  20                              1365
#
#        order_status customer_state seller_state product_category_name
# count         66136          66136        66136                 66136
# unique            5             27           21                    74
# top       delivered             SP           SP       cama_mesa_banho
# freq          64885          27782        47523                  6577

# %%
tb_pedidos.select_dtypes(include=["datetime"]).describe(datetime_is_numeric=True)
# Out:
#                    order_approved_at            shipping_limit_date  \
# count                          66136                          66136
# mean   2018-02-11 11:07:16.559044864  2018-02-17 16:20:51.841478144
# min              2017-08-01 00:15:18            2017-08-07 00:15:18
# 25%       2017-11-25 04:39:01.500000            2017-11-30 19:53:46
# 50%              2018-02-16 10:10:25            2018-02-22 11:52:57
# 75%       2018-05-04 14:53:28.500000     2018-05-10 10:30:18.500000
# max              2018-07-31 23:44:07            2018-08-29 12:30:12
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                          65536                          64881
# mean   2018-02-14 13:42:09.620117248  2018-02-24 02:56:05.722954240
# min              2017-08-01 12:08:02            2017-08-02 16:13:08
# 25%    2017-11-28 22:31:52.750000128            2017-12-08 14:33:51
# 50%              2018-02-20 19:04:19            2018-03-03 00:51:44
# 75%              2018-05-07 19:09:00            2018-05-15 14:26:52
# max              2018-08-22 15:07:00            2018-10-17 13:22:46
#
#        order_estimated_delivery_date
# count                          66136
# mean   2018-03-06 22:11:45.890891264
# min              2017-08-10 00:00:00
# 25%              2017-12-18 00:00:00
# 50%              2018-03-13 00:00:00
# 75%              2018-05-25 00:00:00
# max              2018-09-20 00:00:00

# %%
tb_pedidos.select_dtypes(include=["datetime"]).columns
# Out:
# Index(['order_approved_at', 'shipping_limit_date',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date'],
#       dtype='object')

# %%
colunas_data = tb_pedidos.select_dtypes(include=["datetime"]).columns

for coluna in colunas_data:
    tb_pedidos[coluna] = tb_pedidos[coluna].dt.normalize()

# %%
tb_pedidos.head()
# Out:
#                            order_id                         seller_id   price  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202   58.90
# 1  000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d  199.00
# 2  0005a1a1728c9d785b8e2b08b904576c  a416b6a846a11724393025641d4edd5e  145.95
# 3  0005f50442cb953dcd1d21e1fb923495  ba143b05f0110f0dc71ad71b4466ce92   53.99
# 4  00061f2a7bc09da83e415a52dc8a4af1  cc419e0650a3c5ba77189a1882b7556a   59.99
#
#    freight_value order_status order_approved_at shipping_limit_date  \
# 0          13.29    delivered        2017-09-13          2017-09-19
# 1          17.87    delivered        2018-01-14          2018-01-18
# 2          11.65    delivered        2018-03-20          2018-03-26
# 3          11.40    delivered        2018-07-02          2018-07-06
# 4           8.88    delivered        2018-03-24          2018-03-29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-09-19                    2017-09-20
# 1                   2018-01-16                    2018-01-22
# 2                   2018-03-28                    2018-03-29
# 3                   2018-07-03                    2018-07-04
# 4                   2018-03-27                    2018-03-29
#
#   order_estimated_delivery_date customer_state seller_state  \
# 0                    2017-09-29             RJ           SP
# 1                    2018-02-05             MG           MG
# 2                    2018-03-29             SP           SP
# 3                    2018-07-23             SP           SP
# 4                    2018-04-09             SP           SP
#
#   product_category_name  product_weight_g  review_score
# 0            cool_stuff             650.0             5
# 1      moveis_decoracao            3050.0             5
# 2          beleza_saude            2000.0             1
# 3       livros_tecnicos             850.0             4
# 4          beleza_saude             950.0             5

# %%
tb_pedidos["atraso"] = (
    tb_pedidos["order_delivered_customer_date"]
    > tb_pedidos["order_estimated_delivery_date"]
)
tb_pedidos.loc[~tb_pedidos["atraso"], "dias_atraso"] = 0tb_pedidos.head()
# Out:
#                            order_id                         seller_id   price  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202   58.90
# 1  000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d  199.00
# 2  0005a1a1728c9d785b8e2b08b904576c  a416b6a846a11724393025641d4edd5e  145.95
# 3  0005f50442cb953dcd1d21e1fb923495  ba143b05f0110f0dc71ad71b4466ce92   53.99
# 4  00061f2a7bc09da83e415a52dc8a4af1  cc419e0650a3c5ba77189a1882b7556a   59.99
#
#    freight_value order_status order_approved_at shipping_limit_date  \
# 0          13.29    delivered        2017-09-13          2017-09-19
# 1          17.87    delivered        2018-01-14          2018-01-18
# 2          11.65    delivered        2018-03-20          2018-03-26
# 3          11.40    delivered        2018-07-02          2018-07-06
# 4           8.88    delivered        2018-03-24          2018-03-29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-09-19                    2017-09-20
# 1                   2018-01-16                    2018-01-22
# 2                   2018-03-28                    2018-03-29
# 3                   2018-07-03                    2018-07-04
# 4                   2018-03-27                    2018-03-29
#
#   order_estimated_delivery_date customer_state seller_state  \
# 0                    2017-09-29             RJ           SP
# 1                    2018-02-05             MG           MG
# 2                    2018-03-29             SP           SP
# 3                    2018-07-23             SP           SP
# 4                    2018-04-09             SP           SP
#
#   product_category_name  product_weight_g  review_score  atraso
# 0            cool_stuff             650.0             5   False
# 1      moveis_decoracao            3050.0             5   False
# 2          beleza_saude            2000.0             1   False
# 3       livros_tecnicos             850.0             4   False
# 4          beleza_saude             950.0             5   False

# %%
tb_pedidos.loc[~tb_pedidos["atraso"], "dias_atraso"] = 0

tb_pedidos.loc[tb_pedidos["atraso"], "dias_atraso"] = (
    tb_pedidos["order_delivered_customer_date"]
    - tb_pedidos["order_estimated_delivery_date"]
) / np.timedelta64(1, "D")

# %%
tb_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66136 entries, 0 to 66135
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       66136 non-null  object
#  1   seller_id                      66136 non-null  object
#  2   price                          66136 non-null  float64
#  3   freight_value                  66136 non-null  float64
#  4   order_status                   66136 non-null  object
#  5   order_approved_at              66136 non-null  datetime64[ns]
#  6   shipping_limit_date            66136 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   65536 non-null  datetime64[ns]
#  8   order_delivered_customer_date  64881 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  66136 non-null  datetime64[ns]
#  10  customer_state                 66136 non-null  object
#  11  seller_state                   66136 non-null  object
#  12  product_category_name          66136 non-null  object
#  13  product_weight_g               66134 non-null  float64
#  14  review_score                   66136 non-null  int64
#  15  atraso                         66136 non-null  bool
#  16  dias_atraso                    66136 non-null  float64
# dtypes: bool(1), datetime64[ns](5), float64(4), int64(1), object(6)
# memory usage: 8.1+ MB

# %%
tb_pedidos = tb_pedidos.dropna().copy()
tb_pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64878 entries, 0 to 66135
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       64878 non-null  object
#  1   seller_id                      64878 non-null  object
#  2   price                          64878 non-null  float64
#  3   freight_value                  64878 non-null  float64
#  4   order_status                   64878 non-null  object
#  5   order_approved_at              64878 non-null  datetime64[ns]
#  6   shipping_limit_date            64878 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   64878 non-null  datetime64[ns]
#  8   order_delivered_customer_date  64878 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  64878 non-null  datetime64[ns]
#  10  customer_state                 64878 non-null  object
#  11  seller_state                   64878 non-null  object
#  12  product_category_name          64878 non-null  object
#  13  product_weight_g               64878 non-null  float64
#  14  review_score                   64878 non-null  int64
#  15  atraso                         64878 non-null  bool
#  16  dias_atraso                    64878 non-null  float64
# dtypes: bool(1), datetime64[ns](5), float64(4), int64(1), object(6)
# memory usage: 8.5+ MB

# %% [markdown]
# ## Usando Paletas de Cor
#
# Um dos principais elementos na gramática dos gráficos é a cor. Podemos utilizar a cor de forma gradual (através de **paletas uniformes ou divergentes**) para representar variáveis continuas ou então de forma discreta (através de **paletas qualitativas**).
#
# A biblioteca `seaborn` vem com algumas paletas de cores pré-configuradas, as quais podemos investigar e acessar através da função `color_palette()`. Esta função nos permite visualizar os elementos discretos de uma paleta através de seu nome, e acessar cada cor especificamente através de sua indexação.

# %%
sns.color_palette("Paired")
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %% [markdown]
# Para padronizar a utilização de cores podemos guardar paletas em variáveis para utilização futura:

# %%
colors_discrete = sns.color_palette("Paired")

# %%
colors_discrete
# Out:
# [(0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.984313725490196, 0.6039215686274509, 0.6),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (0.9921568627450981, 0.7490196078431373, 0.43529411764705883),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.792156862745098, 0.6980392156862745, 0.8392156862745098),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (1.0, 1.0, 0.6),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
#fe4656

# %% [markdown]
# Vamos criar um subset desta paleta, mantendo apenas as cores fortes:

# %%
colors_discrete_strong = [color for color in colors_discrete if colors_discrete.index(color) % 2 != 0]

# %%
colors_discrete_strong
# Out:
# [(0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  (0.2, 0.6274509803921569, 0.17254901960784313),
#  (0.8901960784313725, 0.10196078431372549, 0.10980392156862745),
#  (1.0, 0.4980392156862745, 0.0),
#  (0.41568627450980394, 0.23921568627450981, 0.6039215686274509),
#  (0.6941176470588235, 0.34901960784313724, 0.1568627450980392)]

# %%
sns.color_palette("icefire", as_cmap=True)

# %%
colors_cont = sns.color_palette("icefire", as_cmap=True)

# %% [markdown]
# ## Distribuição e Evolução de Avaliações
#
# Vamos inicializar nossa análise investigando a distribuição e evolução histórica das avaliações.

# %%
sns.histplot(data=tb_pedidos, x="review_score")
# Out:
# <AxesSubplot: xlabel='review_score', ylabel='Count'>

# %% [markdown]
# Como as notas dadas pelos clientes são discretas (de 1 à 5 estrelas provavelmente), nosso histograma se parece mais com um barplot. Para facilitar a leitura vamos utilizar um barplot diretamente:

# %%
sns.countplot(data=tb_pedidos, x="review_score", palette = colors_discrete_strong)
# Out:
# <AxesSubplot: xlabel='review_score', ylabel='count'>

# %% [markdown]
# Podemos ver que existe uma concentração de avaliações nos valores extremos (1 e 5) - vamos agrupar essas notas em duas categorias, marcando as notas 1, 2 e 3 como `detractor`.

# %%
tb_pedidos["detractor"] = np.where(tb_pedidos["review_score"] <= 3, 1, 0)

# %% [markdown]
# Para visualizar a evolução histórica das avaliações precisamos agrupar os pedidos (granularidade do nosso `DataFrame`) em **time buckets**, intervalos de tempo fixos. Vamos utilizar **time buckets** diários para esta análise.

# %%
tb_diaria = (
    tb_pedidos.groupby("order_approved_at")
    .agg(
        num_pedidos=pd.NamedAgg("order_id", "nunique"),
        avg_review=pd.NamedAgg("review_score", "mean"),
        std_review=pd.NamedAgg("review_score", "std"),
        per_detractor=pd.NamedAgg("detractor", "mean"),
        per_atraso=pd.NamedAgg("atraso", "mean"),
        avg_atraso=pd.NamedAgg("dias_atraso", "mean"),
    )
    .reset_index()
)

# %%
tb_diaria
# Out:
#     order_approved_at  num_pedidos  avg_review  std_review  per_detractor  \
# 0          2017-08-01           93    4.247706    1.270433       0.192661
# 1          2017-08-02          161    4.250000    1.207122       0.193182
# 2          2017-08-03          120    4.217391    1.242432       0.202899
# 3          2017-08-04          102    4.308333    1.043554       0.175000
# 4          2017-08-05           97    4.363636    1.163097       0.145455
# ..                ...          ...         ...         ...            ...
# 356        2018-07-27          182    4.406250    1.033153       0.133929
# 357        2018-07-28          135    4.518750    0.938163       0.118750
# 358        2018-07-29           88    4.527473    0.935006       0.087912
# 359        2018-07-30          215    4.248945    1.157716       0.160338
# 360        2018-07-31          266    4.232026    1.257797       0.179739
#
#      per_atraso  avg_atraso
# 0      0.018349    0.137615
# 1      0.028409    0.380682
# 2      0.021739    0.159420
# 3      0.041667    0.400000
# 4      0.018182    0.081818
# ..          ...         ...
# 356    0.013393    0.183036
# 357    0.006250    0.043750
# 358    0.021978    0.175824
# 359    0.059072    0.345992
# 360    0.049020    0.199346
#
# [361 rows x 7 columns]

# %% [markdown]
# Vamos utilizar diferentes gráficos de linha para avaliar a evolução do número de pedidos, atrasos e avaliações:

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(data=tb_diaria, x="order_approved_at", y="num_pedidos")
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='num_pedidos'>

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(data=tb_diaria, x="order_approved_at", y="avg_review")
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='avg_review'>

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(data=tb_diaria, x="order_approved_at", y="per_detractor")
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='per_detractor'>

# %%
plt.figure(figsize=(12, 4))
sns.lineplot(data=tb_diaria, x="order_approved_at", y="std_review")
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='std_review'>

# %%
tb_diaria["cv_review"] = tb_diaria["std_review"] / tb_diaria["avg_review"]

plt.figure(figsize=(12, 4))
sns.lineplot(data=tb_diaria, x="order_approved_at", y="cv_review")
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='cv_review'>

# %%
fig, ax = plt.subplots(4, 1, figsize=(12, 16))

sns.lineplot(data=tb_diaria, x="order_approved_at", y="num_pedidos", ax=ax[0])
sns.lineplot(data=tb_diaria, x="order_approved_at", y="avg_review", ax=ax[1])
sns.lineplot(data=tb_diaria, x="order_approved_at", y="cv_review", ax=ax[2])
sns.lineplot(data=tb_diaria, x="order_approved_at", y="per_detractor", ax=ax[3])
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='per_detractor'>

# %% [markdown]
# Embora a análise das séries diárias nos permita ver fenômenos como a sazonalidade de dia da semana e eventuais outliers, a alta frequência da série pode ocultar padrões mais estáveis. Vamos suaziar estas séries utilizando médias móveis:

# %%
tb_diaria["mm_num_pedidos"] = tb_diaria["num_pedidos"].rolling(7).mean()
tb_diaria["mm_avg_review"] = tb_diaria["avg_review"].rolling(7).mean()
tb_diaria["mm_cv_review"] = tb_diaria["cv_review"].rolling(7).mean()
tb_diaria["mm_per_detractor"] = tb_diaria["per_detractor"].rolling(7).mean()
tb_diaria["mm_per_atraso"] = tb_diaria["per_atraso"].rolling(7).mean()
tb_diaria.head(10)
# Out:
#   order_approved_at  num_pedidos  avg_review  std_review  per_detractor  \
# 0        2017-08-01           93    4.247706    1.270433       0.192661
# 1        2017-08-02          161    4.250000    1.207122       0.193182
# 2        2017-08-03          120    4.217391    1.242432       0.202899
# 3        2017-08-04          102    4.308333    1.043554       0.175000
# 4        2017-08-05           97    4.363636    1.163097       0.145455
# 5        2017-08-06           66    4.220779    1.176786       0.220779
# 6        2017-08-07           85    4.485149    0.923189       0.118812
# 7        2017-08-08          135    4.195946    1.170259       0.189189
# 8        2017-08-09          109    4.359375    1.195361       0.132812
# 9        2017-08-10          124    4.275862    1.266462       0.186207
#
#    per_atraso  avg_atraso  cv_review  mm_num_pedidos  mm_avg_review  \
# 0    0.018349    0.137615   0.299087             NaN            NaN
# 1    0.028409    0.380682   0.284029             NaN            NaN
# 2    0.021739    0.159420   0.294597             NaN            NaN
# 3    0.041667    0.400000   0.242218             NaN            NaN
# 4    0.018182    0.081818   0.266543             NaN            NaN
# 5    0.025974    0.272727   0.278808             NaN            NaN
# 6    0.019802    0.108911   0.205832      103.428571       4.298999
# 7    0.027027    0.182432   0.278902      109.428571       4.291605
# 8    0.023438    0.406250   0.274205      102.000000       4.307230
# 9    0.041379    0.324138   0.296189      102.571429       4.315583
#
#    mm_cv_review  mm_per_detractor  mm_per_atraso
# 0           NaN               NaN            NaN
# 1           NaN               NaN            NaN
# 2           NaN               NaN            NaN
# 3           NaN               NaN            NaN
# 4           NaN               NaN            NaN
# 5           NaN               NaN            NaN
# 6      0.267302          0.178398       0.024874
# 7      0.264418          0.177902       0.026114
# 8      0.263015          0.169278       0.025404
# 9      0.263242          0.166893       0.028210

# %%
fig, ax = plt.subplots(2, 1, figsize = (10, 5))
sns.lineplot(data = tb_diaria, x = "order_approved_at", y = "num_pedidos", ax = ax[0])
sns.lineplot(data = tb_diaria, x = "order_approved_at", y = "mm_num_pedidos", ax = ax[1])
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='mm_num_pedidos'>

# %% [markdown]
# Agora vamos combinar as visualizações que construímos anteriormente (da visão diária) com as novas variáveis que construímos (médias móveis):

# %%
fig, ax = plt.subplots(5, 1, figsize=(9, 12))

sns.scatterplot(
    data=tb_diaria,
    x="order_approved_at",
    y="num_pedidos",
    color=colors_discrete[0],
    ax=ax[0],
    alpha=0.4,
)
sns.lineplot(
    data=tb_diaria,
    x="order_approved_at",
    y="mm_num_pedidos",
    color=colors_discrete[1],
    ax=ax[0],
)

sns.scatterplot(
    data=tb_diaria,
    x="order_approved_at",
    y="avg_review",
    color=colors_discrete[2],
    ax=ax[1],
    alpha=0.9,
)
sns.lineplot(
    data=tb_diaria,
    x="order_approved_at",
    y="mm_avg_review",
    color=colors_discrete[3],
    ax=ax[1],
)

sns.scatterplot(
    data=tb_diaria,
    x="order_approved_at",
    y="cv_review",
    color=colors_discrete[4],
    ax=ax[2],
    alpha=0.9,
)
sns.lineplot(
    data=tb_diaria,
    x="order_approved_at",
    y="mm_cv_review",
    color=colors_discrete[5],
    ax=ax[2],
)

sns.scatterplot(
    data=tb_diaria,
    x="order_approved_at",
    y="per_detractor",
    color=colors_discrete[6],
    ax=ax[3],
    alpha=0.9,
)
sns.lineplot(
    data=tb_diaria,
    x="order_approved_at",
    y="mm_per_detractor",
    color=colors_discrete[7],
    ax=ax[3],
)
sns.scatterplot(
    data=tb_diaria,
    x="order_approved_at",
    y="per_atraso",
    color=colors_discrete[8],
    ax=ax[4],
    alpha=0.9,
)
sns.lineplot(
    data=tb_diaria,
    x="order_approved_at",
    y="mm_per_atraso",
    color=colors_discrete[9],
    ax=ax[4],
)
# Out:
# <AxesSubplot: xlabel='order_approved_at', ylabel='per_atraso'>

# %% [markdown]
# ## Explorando (co)Relações
#
# Através da **análise de séries temporais** conseguimos encontrar correlações temporais (no nível diário, não do pedido) entre alguns indicadores agregados. Vamos avaliar essas relações mais de perto utilizando *scatterplots* para **visualizar diretamente a estrutura de correlação** entre nossas variáveis temporais.

# %%
tb_diaria.head()
# Out:
#   order_approved_at  num_pedidos  avg_review  std_review  per_detractor  \
# 0        2017-08-01           93    4.247706    1.270433       0.192661
# 1        2017-08-02          161    4.250000    1.207122       0.193182
# 2        2017-08-03          120    4.217391    1.242432       0.202899
# 3        2017-08-04          102    4.308333    1.043554       0.175000
# 4        2017-08-05           97    4.363636    1.163097       0.145455
#
#    per_atraso  avg_atraso  cv_review  mm_num_pedidos  mm_avg_review  \
# 0    0.018349    0.137615   0.299087             NaN            NaN
# 1    0.028409    0.380682   0.284029             NaN            NaN
# 2    0.021739    0.159420   0.294597             NaN            NaN
# 3    0.041667    0.400000   0.242218             NaN            NaN
# 4    0.018182    0.081818   0.266543             NaN            NaN
#
#    mm_cv_review  mm_per_detractor  mm_per_atraso
# 0           NaN               NaN            NaN
# 1           NaN               NaN            NaN
# 2           NaN               NaN            NaN
# 3           NaN               NaN            NaN
# 4           NaN               NaN            NaN

# %%
sns.scatterplot(data=tb_diaria, x="num_pedidos", y="avg_review")
# Out:
# <AxesSubplot: xlabel='num_pedidos', ylabel='avg_review'>

# %%
mask_outlier = (tb_diaria['num_pedidos'] < 500) & (tb_diaria['num_pedidos'] > 50)
sns.scatterplot(data=tb_diaria[mask_outlier],
                x="num_pedidos", 
                y="avg_review")
# Out:
# <AxesSubplot: xlabel='num_pedidos', ylabel='avg_review'>

# %%
sns.scatterplot(data=tb_diaria, x="mm_num_pedidos", y="mm_avg_review")
# Out:
# <AxesSubplot: xlabel='mm_num_pedidos', ylabel='mm_avg_review'>

# %% [markdown]
# Vamos utilizar o elemento cor para representar a taxa de atraso, permitindo visualizarmos a relação entre 3 variáveis diretamente:

# %%
sns.scatterplot(
    data=tb_diaria, 
    x="mm_num_pedidos",
    y="mm_avg_review", 
    hue="per_atraso",
    palette = "Spectral_r")
# Out:
# <AxesSubplot: xlabel='mm_num_pedidos', ylabel='mm_avg_review'>

# %% [markdown]
# Uma deficiência dos scatterplots é o **empilhamento de pontos**, que muitas vezes dificulta a visualização de regiões com maior densidade de pontos. Vamos utilizar a função `kdeplot()` para representar curvas de nível da densidade de pontos.

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 5))
sns.kdeplot(data=tb_diaria, x="mm_num_pedidos", y="mm_avg_review", fill = True, ax = ax[0])
sns.kdeplot(data=tb_diaria, x="mm_per_atraso", y="mm_avg_review", fill = True, ax = ax[1])
# Out:
# <AxesSubplot: xlabel='mm_per_atraso', ylabel='mm_avg_review'>

# %% [markdown]
# ## Relação entre uma variável continua e uma categórica
#
# Agora vamos retornar à nossa base original, no nível linha do pedido, para analisarmos quais fatores discretos impactam a **% de atrasos** observada.

# %%
tb_pedidos = tb_pedidos.merge(
    tb_diaria[["order_approved_at", "num_pedidos"]], on="order_approved_at"
)

# %%
tb_pedidos
# Out:
#                                order_id                         seller_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202
# 1      01156b662f3f47b249b5a8881d205f08  128639473a139ac0f3e5f5ade55873a5
# 2      0184d4ddb259e1a4cfc2871888cf97b8  e333046ce6517bd8bb510291d44f0130
# 3      026d16bd3f41638e1003e974e5487904  b92e3c8f9738272ff7c59e111e108d7c
# 4      0410ab9a8e8b28e6399bca3e89562f95  7d76b645482be4a332374e8223836592
# ...                                 ...                               ...
# 64873  b508f32bf3fa37e0b3e53b309d477674  1f50f920176fa81dab994f9023523100
# 64874  644e4fc3f5cdee08df44f2534319fac8  50bf89f1349bc0409a268c3a49678009
# 64875  7613c3754c405759d9fc074c35a02b3c  5a8e7d5003a1f221f9e1d6e411de7c23
# 64876  7ac8109e735f29d8982f4503586fe59f  5656537e588803a555b8eb41f07a944b
# 64877  d93ed72dc9abec13f2ad4ae2e531fada  8160255418d5aaa7dbdc9f4c64ebda44
#
#         price  freight_value order_status order_approved_at  \
# 0       58.90          13.29    delivered        2017-09-13
# 1       27.90          15.10    delivered        2017-09-13
# 2       75.00          16.16    delivered        2017-09-13
# 3      169.90          69.90    delivered        2017-09-13
# 4       24.90          14.10    delivered        2017-09-13
# ...       ...            ...          ...               ...
# 64873   49.90          13.37    delivered        2018-01-21
# 64874  179.90         102.57    delivered        2018-07-03
# 64875   39.90           7.54    delivered        2018-07-03
# 64876   50.89          22.29    delivered        2018-07-03
# 64877  124.90          15.18    delivered        2018-07-03
#
#       shipping_limit_date order_delivered_carrier_date  \
# 0              2017-09-19                   2017-09-19
# 1              2017-09-19                   2017-09-18
# 2              2017-09-07                   2017-09-04
# 3              2017-10-04                   2017-09-18
# 4              2017-09-19                   2017-09-15
# ...                   ...                          ...
# 64873          2018-01-25                   2018-01-24
# 64874          2018-07-19                   2018-07-03
# 64875          2018-07-05                   2018-07-03
# 64876          2018-07-05                   2018-07-05
# 64877          2018-07-05                   2018-07-03
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 0                        2017-09-20                    2017-09-29
# 1                        2017-09-27                    2017-10-03
# 2                        2017-09-09                    2017-09-20
# 3                        2017-10-10                    2017-12-05
# 4                        2017-09-28                    2017-10-03
# ...                             ...                           ...
# 64873                    2018-02-05                    2018-02-14
# 64874                    2018-07-11                    2018-08-06
# 64875                    2018-07-05                    2018-07-16
# 64876                    2018-08-17                    2018-07-23
# 64877                    2018-07-06                    2018-07-20
#
#       customer_state seller_state   product_category_name  product_weight_g  \
# 0                 RJ           SP              cool_stuff             650.0
# 1                 RS           PR             eletronicos             100.0
# 2                 SP           SP   utilidades_domesticas            5750.0
# 3                 PB           MG        moveis_decoracao           13050.0
# 4                 SC           SP               telefonia              50.0
# ...              ...          ...                     ...               ...
# 64873             SP           SP      ferramentas_jardim            1750.0
# 64874             RJ           SP        moveis_decoracao           14800.0
# 64875             SP           SP        moveis_decoracao             530.0
# 64876             SP           DF  informatica_acessorios             263.0
# 64877             SP           SP         cama_mesa_banho            2500.0
#
#        review_score  atraso  dias_atraso  detractor  num_pedidos
# 0                 5   False          0.0          0          162
# 1                 5   False          0.0          0          162
# 2                 5   False          0.0          0          162
# 3                 5   False          0.0          0          162
# 4                 4   False          0.0          0          162
# ...             ...     ...          ...        ...          ...
# 64873             5   False          0.0          0            3
# 64874             5   False          0.0          0            4
# 64875             4   False          0.0          0            4
# 64876             3    True         25.0          1            4
# 64877             4   False          0.0          0            4
#
# [64878 rows x 19 columns]

# %% [markdown]
# Vamos começar analisando a distribuição de peso dos itens comprados pela categorização de avaliação que fizemos:

# %%
sns.boxplot(
    data=tb_pedidos,
    x="detractor",
    y="product_weight_g",
)
# Out:
# <AxesSubplot: xlabel='detractor', ylabel='product_weight_g'>

# %% [markdown]
# Que gráfico horrível! Sempre que observamos uma variável (estritamente positiva) cuja distribuição está muito concentrada em valores baixos mas com muitos outliers, podemos considerar uma transformação logaritmíca para facilitar a visualização dos resultados:

# %%
g = sns.boxplot(
    data=tb_pedidos[tb_pedidos["product_weight_g"] > 0],
    x="detractor",
    y="product_weight_g",
)
g.set_yscale("log")

# %% [markdown]
# Parece que o peso do item comprado não tem impacto sobre a avaliação... Testar variável a variável desta forma pode ser trabalhoso e nem sempre renderá avanços no nosso modelo. Vamos utilizar uma técnica reminescente das regressões lineares para facilitar nossa exploração: a **análise de resíduos (ou erros)**.

# %%
g = sns.boxplot(data=tb_pedidos, x="atraso", y="review_score");

# %% [markdown]
# Claramente o *status* de atraso tem um impacto enorme nas avaliações, mas isso já era um fato conhecido! No entanto temos pedidos com avaliações <= 3 sem que houvesse atraso. Vamos criar uma base filtrada para buscar outros fatores que podem impactar a avaliação do cliente:

# %%
tb_pedidos["atraso"].sum()
# Out:
# 4692

# %%
mask_out = (~tb_pedidos["atraso"]) & (tb_pedidos["review_score"] <= 3)
tb_pedidos_out = tb_pedidos[mask_out].copy()

# %%
tb_pedidos_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12189 entries, 8 to 64863
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       12189 non-null  object
#  1   seller_id                      12189 non-null  object
#  2   price                          12189 non-null  float64
#  3   freight_value                  12189 non-null  float64
#  4   order_status                   12189 non-null  object
#  5   order_approved_at              12189 non-null  datetime64[ns]
#  6   shipping_limit_date            12189 non-null  datetime64[ns]
#  7   order_delivered_carrier_date   12189 non-null  datetime64[ns]
#  8   order_delivered_customer_date  12189 non-null  datetime64[ns]
#  9   order_estimated_delivery_date  12189 non-null  datetime64[ns]
#  10  customer_state                 12189 non-null  object
#  11  seller_state                   12189 non-null  object
#  12  product_category_name          12189 non-null  object
#  13  product_weight_g               12189 non-null  float64
#  14  review_score                   12189 non-null  int64
#  15  atraso                         12189 non-null  bool
#  16  dias_atraso                    12189 non-null  float64
#  17  detractor                      12189 non-null  int64
#  18  num_pedidos                    12189 non-null  int64
# dtypes: bool(1), datetime64[ns](5), float64(4), int64(3), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# Além do atraso, um eixo comum de reclamação é a **qualidade dos produtos** pedidos. Vamos descobrir se existem categorias ofensoras dentro do nosso grupo de pedidos mal-avaliados sem atraso:

# %%
sns.countplot(data=tb_pedidos_out, x="product_category_name");

# %%
(
    tb_pedidos_out.groupby("product_category_name")["order_id"]
    .count()
    .reset_index()
    .sort_values(by = "order_id", ascending = False)
)
# Out:
#      product_category_name  order_id
# 14         cama_mesa_banho      1516
# 43  informatica_acessorios      1037
# 53        moveis_decoracao      1022
# 12            beleza_saude       856
# 32           esporte_lazer       815
# ..                     ...       ...
# 35         fashion_esporte         2
# 66      seguros_e_servicos         1
# 59                pc_gamer         1
# 5       artes_e_artesanato         1
# 36  fashion_roupa_feminina         1
#
# [72 rows x 2 columns]

# %% [markdown]
# O que está errado com esse gráfico?

# %%
tb_cat_out = (
    tb_pedidos_out.groupby("product_category_name")["order_id"]
    .count()
    .reset_index()
    .rename({"order_id": "num_pedidos_out"}, axis=1)
)
tb_cat_out
# Out:
#         product_category_name  num_pedidos_out
# 0                                          186
# 1   agro_industria_e_comercio               23
# 2                   alimentos               39
# 3           alimentos_bebidas               32
# 4                       artes               25
# ..                        ...              ...
# 67    sinalizacao_e_seguranca               28
# 68   tablets_impressao_imagem                6
# 69                  telefonia              496
# 70             telefonia_fixa               34
# 71      utilidades_domesticas              743
#
# [72 rows x 2 columns]

# %%
tb_cat = (
    tb_pedidos.groupby("product_category_name")["order_id"]
    .count()
    .reset_index()
    .rename({"order_id": "num_pedidos_total"}, axis=1)
)
tb_cat
# Out:
#         product_category_name  num_pedidos_total
# 0                                            857
# 1   agro_industria_e_comercio                133
# 2                   alimentos                245
# 3           alimentos_bebidas                172
# 4                       artes                117
# ..                        ...                ...
# 69    sinalizacao_e_seguranca                124
# 70   tablets_impressao_imagem                 32
# 71                  telefonia               2486
# 72             telefonia_fixa                112
# 73      utilidades_domesticas               3775
#
# [74 rows x 2 columns]

# %%
tb_cat = tb_cat.merge(tb_cat_out, on="product_category_name")
tb_cat
# Out:
#         product_category_name  num_pedidos_total  num_pedidos_out
# 0                                            857              186
# 1   agro_industria_e_comercio                133               23
# 2                   alimentos                245               39
# 3           alimentos_bebidas                172               32
# 4                       artes                117               25
# ..                        ...                ...              ...
# 67    sinalizacao_e_seguranca                124               28
# 68   tablets_impressao_imagem                 32                6
# 69                  telefonia               2486              496
# 70             telefonia_fixa                112               34
# 71      utilidades_domesticas               3775              743
#
# [72 rows x 3 columns]

# %%
tb_cat["prop_total"] = tb_cat["num_pedidos_total"] / sum(tb_cat["num_pedidos_total"])
tb_cat
# Out:
#         product_category_name  num_pedidos_total  num_pedidos_out  prop_total
# 0                                            857              186    0.013211
# 1   agro_industria_e_comercio                133               23    0.002050
# 2                   alimentos                245               39    0.003777
# 3           alimentos_bebidas                172               32    0.002652
# 4                       artes                117               25    0.001804
# ..                        ...                ...              ...         ...
# 67    sinalizacao_e_seguranca                124               28    0.001912
# 68   tablets_impressao_imagem                 32                6    0.000493
# 69                  telefonia               2486              496    0.038324
# 70             telefonia_fixa                112               34    0.001727
# 71      utilidades_domesticas               3775              743    0.058195
#
# [72 rows x 4 columns]

# %%
tb_cat["num_pedidos_out_expct"] = tb_cat["prop_total"] * sum(tb_cat["num_pedidos_out"])
tb_cat
# Out:
#         product_category_name  num_pedidos_total  num_pedidos_out  prop_total  \
# 0                                            857              186    0.013211
# 1   agro_industria_e_comercio                133               23    0.002050
# 2                   alimentos                245               39    0.003777
# 3           alimentos_bebidas                172               32    0.002652
# 4                       artes                117               25    0.001804
# ..                        ...                ...              ...         ...
# 67    sinalizacao_e_seguranca                124               28    0.001912
# 68   tablets_impressao_imagem                 32                6    0.000493
# 69                  telefonia               2486              496    0.038324
# 70             telefonia_fixa                112               34    0.001727
# 71      utilidades_domesticas               3775              743    0.058195
#
#     num_pedidos_out_expct
# 0              161.034300
# 1               24.991321
# 2               46.036644
# 3               32.319603
# 4               21.984846
# ..                    ...
# 67              23.300179
# 68               6.012949
# 69             467.131005
# 70              21.045323
# 71             709.340121
#
# [72 rows x 5 columns]

# %%
tb_cat["diff_pedidos_out"] = tb_cat["num_pedidos_out"] - tb_cat["num_pedidos_out_expct"]
tb_cat
# Out:
#         product_category_name  num_pedidos_total  num_pedidos_out  prop_total  \
# 0                                            857              186    0.013211
# 1   agro_industria_e_comercio                133               23    0.002050
# 2                   alimentos                245               39    0.003777
# 3           alimentos_bebidas                172               32    0.002652
# 4                       artes                117               25    0.001804
# ..                        ...                ...              ...         ...
# 67    sinalizacao_e_seguranca                124               28    0.001912
# 68   tablets_impressao_imagem                 32                6    0.000493
# 69                  telefonia               2486              496    0.038324
# 70             telefonia_fixa                112               34    0.001727
# 71      utilidades_domesticas               3775              743    0.058195
#
#     num_pedidos_out_expct  diff_pedidos_out
# 0              161.034300         24.965700
# 1               24.991321         -1.991321
# 2               46.036644         -7.036644
# 3               32.319603         -0.319603
# 4               21.984846          3.015154
# ..                    ...               ...
# 67              23.300179          4.699821
# 68               6.012949         -0.012949
# 69             467.131005         28.868995
# 70              21.045323         12.954677
# 71             709.340121         33.659879
#
# [72 rows x 6 columns]

# %% [markdown]
# Agora podemos visualizar se existem categorias cujo # de pedidos dentro do grupo selecionado (sem atraso) é maior do que o esperado:

# %%
sns.histplot(data=tb_cat, x="diff_pedidos_out")
# Out:
# <AxesSubplot: xlabel='diff_pedidos_out', ylabel='Count'>

# %% [markdown]
# Temos algumas ofensoras claras! Vamos filtrar a tabela acima e selecionar estas categorias:

# %%
cat_problema = set(
    tb_cat.loc[tb_cat["diff_pedidos_out"] > 100, "product_category_name"]
)
cat_problema
# Out:
# {'cama_mesa_banho',
#  'informatica_acessorios',
#  'moveis_decoracao',
#  'moveis_escritorio'}

# %% [markdown]
# Agora vamos utilizar esse conjunto de categorias para realizar um agrupamento da variável categoria na base original de pedidos:

# %%
tb_pedidos.loc[mask_cat, "cat_agg"] = tb_pedidos["product_category_name"]
tb_pedidos.loc[~mask_cat, "cat_agg"] = "Outros"
fig, ax = plt.subplots(figsize = (10, 5))
sns.boxplot(data=tb_pedidos, x="atraso", y="review_score", hue="cat_agg")
# Out:
# <AxesSubplot: xlabel='atraso', ylabel='review_score'>

# %% [markdown]
# A natureza discreta do campo de avaliação dificulta a visualização da distribuição através de boxplots. Vamos utilizar um violin plot para aumentar a

# %%
fig = plt.figure(figsize=(10, 5))
sns.violinplot(data=tb_pedidos, x="cat_agg", y="review_score", hue="atraso", split=True)
# Out:
# <AxesSubplot: xlabel='cat_agg', ylabel='review_score'>

# %% [markdown]
# ## Análises multi-variáveis

# %%
tb_diaria.columns

# %%
var_original = [
    "num_pedidos",
    "avg_review",
    "std_review",
    "per_detractor",
    "per_atraso",
    "avg_atraso",
]
var_mm = ["mm_num_pedidos", "mm_avg_review", "mm_cv_review", "mm_per_detractor"]

# %%
sns.pairplot(tb_diaria[var_original])

# %%
sns.pairplot(tb_diaria[var_mm])

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(tb_diaria[var_original].corr(), vmin=-1, center=0, vmax=1)

# %%
plt.figure(figsize=(12, 9))
sns.clustermap(tb_diaria[var_mm].corr(), vmin=-1, center=0, vmax=1)

# %%
def nps(nota):
    if nota <= 3:
        tipo_cliente = "Detractor"
    elif nota < 5:
        tipo_cliente = "Neutral"
    else:
        tipo_cliente = "Promoter"   
    return tipo_cliente

# %%
tb_pedidos["nps"] = tb_pedidos["review_score"].map(nps)

# %%
tb_pedidos
# Out:
#                                order_id                         seller_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202
# 1      01156b662f3f47b249b5a8881d205f08  128639473a139ac0f3e5f5ade55873a5
# 2      0184d4ddb259e1a4cfc2871888cf97b8  e333046ce6517bd8bb510291d44f0130
# 3      026d16bd3f41638e1003e974e5487904  b92e3c8f9738272ff7c59e111e108d7c
# 4      0410ab9a8e8b28e6399bca3e89562f95  7d76b645482be4a332374e8223836592
# ...                                 ...                               ...
# 64873  b508f32bf3fa37e0b3e53b309d477674  1f50f920176fa81dab994f9023523100
# 64874  644e4fc3f5cdee08df44f2534319fac8  50bf89f1349bc0409a268c3a49678009
# 64875  7613c3754c405759d9fc074c35a02b3c  5a8e7d5003a1f221f9e1d6e411de7c23
# 64876  7ac8109e735f29d8982f4503586fe59f  5656537e588803a555b8eb41f07a944b
# 64877  d93ed72dc9abec13f2ad4ae2e531fada  8160255418d5aaa7dbdc9f4c64ebda44
#
#         price  freight_value order_status order_approved_at  \
# 0       58.90          13.29    delivered        2017-09-13
# 1       27.90          15.10    delivered        2017-09-13
# 2       75.00          16.16    delivered        2017-09-13
# 3      169.90          69.90    delivered        2017-09-13
# 4       24.90          14.10    delivered        2017-09-13
# ...       ...            ...          ...               ...
# 64873   49.90          13.37    delivered        2018-01-21
# 64874  179.90         102.57    delivered        2018-07-03
# 64875   39.90           7.54    delivered        2018-07-03
# 64876   50.89          22.29    delivered        2018-07-03
# 64877  124.90          15.18    delivered        2018-07-03
#
#       shipping_limit_date order_delivered_carrier_date  \
# 0              2017-09-19                   2017-09-19
# 1              2017-09-19                   2017-09-18
# 2              2017-09-07                   2017-09-04
# 3              2017-10-04                   2017-09-18
# 4              2017-09-19                   2017-09-15
# ...                   ...                          ...
# 64873          2018-01-25                   2018-01-24
# 64874          2018-07-19                   2018-07-03
# 64875          2018-07-05                   2018-07-03
# 64876          2018-07-05                   2018-07-05
# 64877          2018-07-05                   2018-07-03
#
#       order_delivered_customer_date order_estimated_delivery_date  ...  \
# 0                        2017-09-20                    2017-09-29  ...
# 1                        2017-09-27                    2017-10-03  ...
# 2                        2017-09-09                    2017-09-20  ...
# 3                        2017-10-10                    2017-12-05  ...
# 4                        2017-09-28                    2017-10-03  ...
# ...                             ...                           ...  ...
# 64873                    2018-02-05                    2018-02-14  ...
# 64874                    2018-07-11                    2018-08-06  ...
# 64875                    2018-07-05                    2018-07-16  ...
# 64876                    2018-08-17                    2018-07-23  ...
# 64877                    2018-07-06                    2018-07-20  ...
#
#       seller_state   product_category_name product_weight_g  review_score  \
# 0               SP              cool_stuff            650.0             5
# 1               PR             eletronicos            100.0             5
# 2               SP   utilidades_domesticas           5750.0             5
# 3               MG        moveis_decoracao          13050.0             5
# 4               SP               telefonia             50.0             4
# ...            ...                     ...              ...           ...
# 64873           SP      ferramentas_jardim           1750.0             5
# 64874           SP        moveis_decoracao          14800.0             5
# 64875           SP        moveis_decoracao            530.0             4
# 64876           DF  informatica_acessorios            263.0             3
# 64877           SP         cama_mesa_banho           2500.0             4
#
#        atraso  dias_atraso  detractor  num_pedidos                 cat_agg  \
# 0       False          0.0          0          162                  Outros
# 1       False          0.0          0          162                  Outros
# 2       False          0.0          0          162                  Outros
# 3       False          0.0          0          162        moveis_decoracao
# 4       False          0.0          0          162                  Outros
# ...       ...          ...        ...          ...                     ...
# 64873   False          0.0          0            3                  Outros
# 64874   False          0.0          0            4        moveis_decoracao
# 64875   False          0.0          0            4        moveis_decoracao
# 64876    True         25.0          1            4  informatica_acessorios
# 64877   False          0.0          0            4         cama_mesa_banho
#
#              nps
# 0       Promoter
# 1       Promoter
# 2       Promoter
# 3       Promoter
# 4        Neutral
# ...          ...
# 64873   Promoter
# 64874   Promoter
# 64875    Neutral
# 64876  Detractor
# 64877    Neutral
#
# [64878 rows x 21 columns]

# %%
cat_problema
# Out:
# {'cama_mesa_banho',
#  'informatica_acessorios',
#  'moveis_decoracao',
#  'moveis_escritorio'}

# %%
tb_pedidos["product_category_name"].map(lambda x: x in cat_problema)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 64873    False
# 64874     True
# 64875     True
# 64876     True
# 64877     True
# Name: product_category_name, Length: 64878, dtype: bool

# %%
tb_pedidos[["price", "freight_value"]].apply(np.mean, axis = 1)
# Out:
# 0         36.095
# 1         21.500
# 2         45.580
# 3        119.900
# 4         19.500
#           ...
# 64873     31.635
# 64874    141.235
# 64875     23.720
# 64876     36.590
# 64877     70.040
# Length: 64878, dtype: float64

# %%
def frete_maior(preco, frete):
    if frete > preco:
        status = "Frete maior"
    else:
        status = "Frete menor"
    return status

# %%
(
    tb_pedidos[["price", "freight_value"]]
    .apply(lambda x: frete_maior(x['price'], x['freight_value']), axis = 1)
)
# Out:
# 0        Frete menor
# 1        Frete menor
# 2        Frete menor
# 3        Frete menor
# 4        Frete menor
#             ...
# 64873    Frete menor
# 64874    Frete menor
# 64875    Frete menor
# 64876    Frete menor
# 64877    Frete menor
# Length: 64878, dtype: object
